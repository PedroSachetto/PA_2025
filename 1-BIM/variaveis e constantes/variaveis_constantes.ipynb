# %% [markdown]
# #variaveis e constates

# %%
idade = 14
altura = 1.73
nome ="Pedro Sachetto"
vai = True

# %%
nomes = ["Pedro Sachetto","Taty"]
nomes2 = ("Pedro Sachetto","Taty")
tudo ={nome:"Pedro Sachetto",idade:14,altura:1.70}

# %%
print(nome)
print(nomes)
print(nomes2)
print(tudo)
# Out:
# Pedro Sachetto
# ['Pedro Sachetto', 'Taty']
# ('Pedro Sachetto', 'Taty')
# {'Pedro Sachetto': 'Pedro Sachetto', 14: 14, 1.73: 1.7}

# %%
print(type(nome))
print(type(nomes))
print(type(nomes2))
print(type(idade))
print(type(vai))
print(type(altura))
print(type(tudo))
# Out:
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# <class 'dict'>

# %%
print("o nome dele é:",nome,",sua idade é :",idade,"anos,ele tem", altura,"metros")
# Out:
# o nome dele é: Pedro Sachetto ,sua idade é : 14 anos,ele tem 1.73 metros

# %%
print(f"nome: {nome},altura:{altura}")
# Out:
# nome: Pedro Sachetto,altura:1.73

# %% [markdown]
# #area do circulo#

# %%
PI = 3.14159
raio =  float (input("Digite o valor do raio do circulo: "))
# Out:
# Digite o valor do raio do circulo: 4

# %%
areacir = PI * (raio**2)

# %%
print(f"Area do circulo é {areacir}")
# Out:
# Area do circulo é 50.26544

# %% [markdown]
# #area do quadrdo#

# %%
lado =float(input("digite o valor do lado do quadrado"))
# Out:
# digite o valor do lado do quadrado4

# %%
areaqua = lado **2

# %%
print(f"Area do quadrado é:{areaqua}")
# Out:
# Area do quadrado é:16.0

# %% [markdown]
# #Exercicios

# %% [markdown]
# #Exercicio 1

# %%
#entrada

Base = float(input("Digite o valor da Base"))
# Out:
# Digite o valor da Base5

# %%
altura = float(input("Digite o valor da Altura"))
# Out:
# Digite o valor da Altura3

# %%
#processamento
areadore = Base * altura

# %%
#saida
print(f"Area Do Retangulo é :{areadore}")
# Out:
# Area Do Retangulo é :15.0

# %% [markdown]
# #Exercicio 2

# %%
#entrada
PI = 3.1416
Raio = float(input("Digite o valor d o raio"))
# Out:
# Digite o valor d o raio5

# %%
#processamento
Perimetro = 2 * PI * Raio

# %%
print(f"o valor do perimetro é : {Perimetro}")
# Out:
# o valor do perimetro é : 31.416

# %% [markdown]
# #Exercicio 3

# %%
# entrada

F = float(input("Digite o valor da Temperatura Em Fahrenheit"))
# Out:
# Digite o valor da Temperatura Em Fahrenheit124

# %%
#processamento
C = (F - 32) * 5/9

# %%
 #saida
 print(f"a conversao Da teperatura em Celsius é : {C}")
# Out:
# a conversao Da teperatura em Celsius é : 51.111111111111114

# %% [markdown]
# #Exercicio 4

# %%
#entrada
peso = float(input("Digite o valor do peso"))
altura= float(input("Digite o valor da altura"))
# Out:
# Digite o valor do peso500
# Digite o valor da altura1.50

# %%
#processamento
IMA = peso/altura**2

# %%
print(f"O IMA é:{IMA}")
# Out:
# O IMA é:222.22222222222223

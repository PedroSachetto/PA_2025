# %% [markdown]
# #TIPOS DE CONDICIONAIS
# CONDICIONAIS SIMPLES:Possui apenas duas possibilidades(True or False)

# %%
#entrada

nota1= float(input("Digite a primeira nota"))
if( nota1>=0 and nota1<=10):
  print("Nota 1 computada")
else:
  print("Nota Não Computada")
  print("Execute novamente o programa")

nota2= float(input("Digite a primeira nota"))
if( nota2>=0 and nota2<=10):
  print("Nota 2 computada")
else:
  print("Nota Não Computada")
  print("Execute novamente o programa")

nota3= float(input("Digite a primeira nota"))
if( nota3>=0 and nota3<=10):
  print("Nota 3 computada")
else:
  print("Nota Não Computada")
  print("Execute novamente o programa")


#processamento
MEDIA = (nota1+nota2+nota3)/3
if(MEDIA>=7):
  print("você foi aprovado")
else:
  print("você foi reprovado")

#saida
print(MEDIA)
# Out:
# Digite a primeira nota10
# Nota 1 computada
# Digite a primeira nota10
# Nota 2 computada
# Digite a primeira nota10
# Nota 3 computada
# você foi aprovado
# 10.0

# %% [markdown]
# #CONDICIONAL COMPOSTO
# ##POSSUI MAIS DE DUAS POSSIBILIDADES DE DECISÂO

# %%
nota1= float(input("Digite a nota 1"))
if( nota1>=0 and nota1<=10):
  print("Nota 1 computada")
else:
  print("Nota Não Computada")
  print("Execute novamente o programa")

nota2= float(input("Digite a nota 2"))
if( nota2>=0 and nota2<=10):
  print("Nota 2 computada")
else:
  print("Nota Não Computada")
  print("Execute novamente o programa")

nota3= float(input("Digite a nota 3"))
if( nota3>=0 and nota3<=10):
  print("Nota 3 computada")
else:
  print("Nota Não Computada")
  print("Execute novamente o programa")


#processamento
MEDIA = (nota1+nota2+nota3)/3
print(MEDIA)
# Out:
# Digite a nota 10
# Nota 1 computada
# Digite a nota 20
# Nota 2 computada
# Digite a nota 310
# Nota 3 computada
# 3.3333333333333335

# %%
if (MEDIA<5):
  print("Sua menção final é I")
elif (MEDIA>=5) and (MEDIA<6.5):
  print("Sua menção final é R")
elif (MEDIA>=6.5) and (MEDIA<8.5):
  print("Sua menção final é B")
else:
    print("Sua menção final é MB")
# Out:
# Sua menção final é I

# %% [markdown]
# #Condicional Aninhado
# ##quando o segundo if só é executado se o primeiro for true

# %%
usuario = input("Digite o usuário : ")


usuariocerto = "sachetto13"
senhacerta = "130610"

if(usuario == usuariocerto):
  senha =  input("Digite a senha :")
  if (senha == senhacerta):
   print("Usuário logado")
  else:
    print("senha incorreta")
else:
    print("usuário incorreto")
# Out:
# Digite o usuário : sachetto13
# Digite a senha :130610
# Usuário logado

# %% [markdown]
# ##EXERCICIOS

# %% [markdown]
# 1)Faça um programa que solicite ao usuário três valores (lados de um triangulo), verifique se é um triangulo e informe se ele é isóceles, equilatero ou escaleno.

# %%
lado1 = float(input("digite o valor do lado 1 do triangulo: "))
lado2 = float(input("digite o valor do lado 2 do triangulo: "))
lado3 = float(input("digite o valor do lado 3 do triangulo: "))


if ((lado1 + lado2 + lado3) and (lado1 + lado3 >lado2) and (lado2 +lado3 > lado1)):
  if (lado1 == lado2 == lado3):
    print("Triangulo Equilátero")
  elif ((lado1 != lado2 and lado1 !=lado3)):
    print("Triangulo Escaleno")
  else:
    print("Triangulo Isósceles")
else:
  print("Lados não formam um triangulo")

# %% [markdown]
# 2)Peça para o usuário digitar um valor informe se ele é par ou impar

# %%
numero = int(input("digite um numero: "))
if numero%2==0:
    print("Esse número é par")
else:
  print("Esse número é impar")
# Out:
# digite um numero: 9
# Esse número é impar

# %% [markdown]
# 3)Faça um programa que solicite peso e altura, informe seu IMC. Ao final informe se ele está, abaixo do peso,peso ideal ou acima do peso. fórmula do IMC: (peso/altura^2), siga a tabela abaixo:I

# %%
peso = float(input("Digite seu peso (em quilos):"))
altura = float(input("Digite sua altura (em metros):"))
altura2 = altura * altura
imc = peso / altura2

if imc <= 18.5:
  print("Você está abaixo do peso")
elif 18.5 <= imc <= 24.9:
  print("Você está no peso certo")
elif 25 <= imc <= 29.9:
  print("Você está em sobrepeso")
elif 30 <= imc <= 34.9:
  print("Você tem obesidade  nível 1 ")
elif 35 <= imc <= 39.9:
  print("Você tem obesidade  nível 2 ")
else:
  print("Você tem obesidade nível 3 ")
# Out:
# Digite seu peso (em quilos):78
# Digite sua altura (em metros):1.71
# Você está em sobrepeso

# %% [markdown]
# 4)Caixa Eletrônico com Login e Operações Bancárias

# %%
cpf = input("Digite o CPF : ")
senha =  input("Digite a senha :")

cpfcerto = "123456"
senhacerta = "1234"

if(cpf == cpfcerto):
  if (senha == senhacerta):
   print("CONTA LOGADA")
  else:
    print("senha incorreta")
else:
    print("CPF OU SENHA INCORRETOS,TENTE NOVAMENTE")
# Out:
# Digite o CPF : 6464
# Digite a senha :36516165
# CPF OU SENHA INCORRETOS,TENTE NOVAMENTE

# %% [markdown]
# 5)Simulador de Saque e Depósito com Limite

# %%
cpfcerto1 = "123456"
senhacerta1 = "1234"
saldo = 1000
limite = 500

cpf1 = input("Digite o CPF : ")
if(cpf1 == cpfcerto1):

  senha1 =  input("Digite a senha :")
  if (senha1 == senhacerta1):
   print("CONTA LOGADA")
   opcao = int(input("O QUE QUER FAZER \nDigite 1 para SACAR \nDigite 2 para DEPOSITAR \nDigite 3 para SALDO: "))

   if (opcao == 1 ):
     sacar = float(input("QUANTO QUER SACAR:"))
     saldo1 = (saldo - sacar)
     if (saldo1 < limite):
      print("NÃO É POSSIVEL SACAR MAIS DE:",limite)
      print("SALDO NEGATIVO:",saldo1)
     else:
        print("SAQUE FEITO  COM SUCESSO,VALOR RESTANTE:",saldo1)

   if (opcao == 2):
      valor = float(input("QUANTO QUER DEPOSITAR:"))
      if (valor > 0):
        saldo2 = (saldo + valor)
        print("DEPOSITO FEITO COM SUCESSO, SEU SALDO AGORA É DE:",saldo2)
      else:
        print("NÃO FOI POSSIVEL REALIZAR O DEPOSITO!!!")


   if (opcao == 3):
        print("SALDO É:",saldo)



else:
    print("CPF OU SENHA INCORRETOS,TENTE NOVAMENTE")
# Out:
# Digite o CPF : 123456
# Digite a senha :1234
# CONTA LOGADA
# O QUE QUER FAZER
# Digite 1 para SACAR
# Digite 2 para DEPOSITAR
# Digite 3 para SALDO: 2
# QUANTO QUER DEPOSITAR:200
# DEPOSITO FEITO COM SUCESSO, SEU SALDO AGORA É DE: 1200.0

# %% [markdown]
# 6)Faça um programa que solicite altura e idade do usuário, informe se ele pode ou nao competir.

# %%
iddades= int(input("Sua idade:"))
altura = float(input("Qual é sua altura"))


if(iddades>=18 and altura>=1.75):
  print("Pode ir na competição")
else:
  print("Não pode competir")
# Out:
# Sua idade:32
# Qual é sua altura1.32
# Não pode competir

# %% [markdown]
# 7)Faça um programa que solicite o peso do lutador de Boxe. Informe em que categoria de boxe o usuário está

# %%
pesso = float(input("Digite o peso do lutador em kg: "))

if pesso <= 46.27:
    print("Categoria: Palha Ligeiro")

elif (pesso <= 47.63):
    print("Categoria: Palha")

elif (pesso <= 48.99):
    print("Categoria: Mosca Ligeiro")

elif (pesso <= 50.35):
    print("Categoria: Mosca")

elif (pesso <= 51.71):
    print("Categoria: Super Mosca")

elif (pesso <= 53.52):
    print("Categoria: Galo")

elif (pesso <= 55.34):
    print("Categoria: Super Galo")

elif (pesso <= 57.15):
    print("Categoria: Pena")

elif (pesso <= 58.97):
    print("Categoria: Super Pena")

elif (pesso <= 61.23):
    print("Categoria: Leve")

elif (pesso <= 63.5):
    print("Categoria: Super Leve")

elif (pesso <= 66.68):
    print("Categoria: Meio-Médio")

elif (pesso <= 69.85):
    print("Categoria: Super Meio-Médio")

elif (pesso <= 73.03):
    print("Categoria: Médio")

elif (pesso <= 76.2):
    print("Categoria: Super Médio")

elif (pesso <= 79.38):
    print("Categoria: Meio-Pesado")

elif (pesso <= 90.72):
    print("Categoria: Cruzador")

else:
    print("Categoria: Pesado")
# Out:
# Digite o peso do lutador em kg: 200
# Categoria: Pesado

# %% [markdown]
# 8)Faça um programa que solicite o salário do usuário e informe quanto esse usuário irá pagar de imposto de Renda.

# %%
salario1 = float(input("COLOQUE O SEU SALÁRIO:"))

if (salario1 <= 1903.98):
  imposto = 0
  print("NÃO IRA PAGAR IMPOSTO DE RENDA",imposto)

elif (salario1 <= 2826.65):
  imposto1 = (salario1* 0.075)
  print("VOCÊ IRÁ PAGAR:",imposto1, "DE IMPOSTO DE RENDA")

elif (salario1 <= 3751.05):
  imposto2 = (salario1* 0.15)
  print("VOCÊ IRÁ PAGAR:",imposto2, "DE IMPOSTO DE RENDA")

elif (salario1 <= 4664.68):
  imposto3 = (salario1* 0.225)
  print("VOCÊ IRÁ PAGAR:",imposto3, "DE IMPOSTO DE RENDA")

else:
    print("NÃO IRA PAGAR IMPOSTO DE RENDA")
# Out:
# COLOQUE O SEU SALÁRIO:4664.68
# VOCÊ IRÁ PAGAR: 1049.553 DE IMPOSTO DE RENDA

# %% [markdown]
# 9)Uma empresa dará aumento para seus funcionários, faça um programa que faça esses cálculos, solicite o salário do funcionário e informe o aumento que o mesmo terá,

# %%
salario = float(input("DIGITE SEU SALARIO : "))

if (salario <= 1500):
    aumento1 = (salario * 0.20)
    novosala1 = salario + aumento1
    print("Seu novo salário é:",novosala1)

elif (salario <= 3000):
    aumento2 = (salario * 0.15)
    novosala2 = salario + aumento2
    print("Seu novo salário é:",novosala2)

else:
    aumento3 = (salario * 0.10)
    novosala3 = salario + aumento3
    print("Seu novo salário é:",novosala3)
# Out:
# DIGITE SEU SALARIO : 1800
# Seu novo salário é: 2070.0

# %% [markdown]
# 10)Simulador de frete inteligente que peça o peso do pacote (em kg) e a distância (em km) de sua cidade até o local de entrega

# %%
pessso = float(input("COLOQUE O PESO DO PACOTE EM KG:"))
distancia = float(input("COLOQUE A DISTÁNCIA EM KM:"))

if (pessso <= 2):
  frete1 = distancia/100 * 5
  print("O VALOR DO FRETE FICOU:",frete1)

elif(pessso <= 5):
  frete2 = distancia/100 * 8
  print("O VALOR DO FRETE FICOU:",frete2)

else:
  frete3 = distancia/100 * 10
  print("O VALOR DO FRETE FICOU:",frete3)
# Out:
# COLOQUE O PESO DO PACOTE EM KG:11
# COLOQUE A DISTÁNCIA EM KM:200
# O VALOR DO FRETE FICOU: 20.0
